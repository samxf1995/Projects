# %% [markdown]
# # Assignment 2: IR

# %% [markdown]
# ## Preparations
# * Put all your imports, and path constants in the next cells
# * Make sure all your path constants are **relative to** ***DATA_DIR*** and **NOT hard-coded** in your code.

# %%
# imports
from whoosh import index, writing
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import *
from whoosh.qparser import QueryParser
import os.path
from pathlib import Path
import tempfile
import subprocess

# %%
DATA_DIR = "government"
#
DOCUMENTS_DIR = os.path.join(DATA_DIR, "documents")
TOPIC_FILE = os.path.join(DATA_DIR, "gov.topics")
QRELS_FILE = os.path.join(DATA_DIR, "gov.qrels")
TREC_EVAL = os.path.join("trec_eval", "trec_eval.exe")

# %% [markdown]
# ## Question 1
# Provide your text answers in the following two markdown cells

# %% [markdown]
# ### Q1 (a): Provide answer to Q1 (a) here [markdown cell]

# %% [markdown]
# MAP

# %% [markdown]
# ### Q1 (b): Provide answer to Q1 (b) here [markdown cell]

# %% [markdown]
# Mean average precision weights high ranked result more, and high score indicates good result.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Q2 (a): Write your code below

# %%
# Put your code for creating the index here (you can add more cells).
# Make sure you save the final index in the variable INDEX_Q2, your query parser in QP_Q2, and your searcher in SEARCHER_Q2
def createIndex(schema):
    # Generate a temporary directory for the index
    indexDir = tempfile.mkdtemp()

    # create and return the index
    return index.create_in(indexDir, schema)

# %%
# first, define a Schema for the index
mySchema = Schema(file_path = ID(stored=True),
                  file_content = TEXT(analyzer = RegexTokenizer()))

# now, create the index at the path INDEX_DIR based on the new schema
myIndex = createIndex(mySchema)

# %%
def addFilesToIndex(indexObj, fileList):
    # open writer
    writer = writing.BufferedWriter(indexObj, period=None, limit=1000)

    try:
        # write each file to index
        for docNum, filePath in enumerate(fileList):
            with open(filePath, "r", encoding="utf-8") as f:
                fileContent = f.read()
                writer.add_document(file_path = filePath,
                                    file_content = fileContent)

                # print status every 1000 documents
                if ((docNum+1) % 1000 == 0):
                    print("already indexed:", docNum+1)
        print("done indexing.")

    finally:
        # close the index
        writer.close()

# %%
# Build a list of files to index
filesToIndex = [str(filePath) for filePath in Path(DOCUMENTS_DIR).glob("**/*") if filePath.is_file()]

# %%
# Check the list
filesToIndex[:5]
# Out:
# ['government\\documents\\00\\G00-00-0088569',
#  'government\\documents\\00\\G00-00-0114013',
#  'government\\documents\\00\\G00-00-0124389',
#  'government\\documents\\00\\G00-00-0158061',
#  'government\\documents\\00\\G00-00-0165832']

# %%
# count files to index
print("number of files:", len(filesToIndex))
# Out:
# number of files: 4078

# %%
addFilesToIndex(myIndex, filesToIndex)
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
# define a query parser for the field "file_content" in the index
myQueryParser = QueryParser("file_content", schema=myIndex.schema)
mySearcher = myIndex.searcher()

# %%
# print the topic file
with open(TOPIC_FILE, "r") as f:
    print(f.read())
# Out:
# 1 mining gold silver coal
# 2 juvenile delinquency
# 4 wireless communications
# 6 physical therapists
# 7 cotton industry
# 9 genealogy searches
# 10 Physical Fitness
# 14 Agricultural biotechnology
# 16 Emergency and disaster preparedness assistance
# 18 Shipwrecks
# 19 Cybercrime, internet fraud, and cyber fraud
# 22 Veteran's Benefits
# 24 Air Bag Safety
# 26 Nuclear power plants
# 28 Early Childhood Education

# %%
def trecEval(topicFile, qrelsFile, queryParser, searcher):
    # Load topic file - a list of topics(search phrases) used for evalutation
    with open(topicFile, "r") as tf:
        topics = tf.read().splitlines()

    # create an output file to which we'll write our results
    tempOutputFile = tempfile.mkstemp()[1]
    with open(tempOutputFile, "w") as outputTRECFile:
        # for each evaluated topic:
        # build a query and record the results in the file in TREC_EVAL format
        for topic in topics:
            topic_id, topic_phrase = tuple(topic.split(" ",1))
            topicQuery = queryParser.parse(topic_phrase)
            topicResults = searcher.search(topicQuery, limit=None)
            for (docnum, result) in enumerate(topicResults):
                score = topicResults.score(docnum)
                outputTRECFile.write("%s Q0 %s %d %lf test\n" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
    result = subprocess.run([TREC_EVAL, '-q', qrelsFile, tempOutputFile], stdout=subprocess.PIPE)
    print(result.stdout.decode())

# %%
trecEval(TOPIC_FILE, QRELS_FILE, myQueryParser, mySearcher)
# Out:
# num_ret               	1	1
# num_rel               	1	5
# num_rel_ret           	1	0
# map                   	1	0.0000
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0000
# iprec_at_recall_0.00  	1	0.0000
# iprec_at_recall_0.10  	1	0.0000
# iprec_at_recall_0.20  	1	0.0000
# iprec_at_recall_0.30  	1	0.0000
# iprec_at_recall_0.40  	1	0.0000
# iprec_at_recall_0.50  	1	0.0000
# iprec_at_recall_0.60  	1	0.0000
# iprec_at_recall_0.70  	1	0.0000
# iprec_at_recall_0.80  	1	0.0000
# iprec_at_recall_0.90  	1	0.0000
# iprec_at_recall_1.00  	1	0.0000
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0000
# P_30                  	1	0.0000
# P_100                 	1	0.0000
# P_200                 	1	0.0000
# P_500                 	1	0.0000
# P_1000                	1	0.0000
# num_ret               	10	16
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.1667
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.1667
# iprec_at_recall_0.00  	10	0.1667
# iprec_at_recall_0.10  	10	0.1667
# iprec_at_recall_0.20  	10	0.1667
# iprec_at_recall_0.30  	10	0.1667
# iprec_at_recall_0.40  	10	0.1667
# iprec_at_recall_0.50  	10	0.1667
# iprec_at_recall_0.60  	10	0.1667
# iprec_at_recall_0.70  	10	0.1667
# iprec_at_recall_0.80  	10	0.1667
# iprec_at_recall_0.90  	10	0.1667
# iprec_at_recall_1.00  	10	0.1667
# P_5                   	10	0.0000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	7
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	0.2500
# Rprec                 	14	0.0000
# bpref                 	14	0.0000
# recip_rank            	14	0.2500
# iprec_at_recall_0.00  	14	0.2500
# iprec_at_recall_0.10  	14	0.2500
# iprec_at_recall_0.20  	14	0.2500
# iprec_at_recall_0.30  	14	0.2500
# iprec_at_recall_0.40  	14	0.2500
# iprec_at_recall_0.50  	14	0.2500
# iprec_at_recall_0.60  	14	0.2500
# iprec_at_recall_0.70  	14	0.2500
# iprec_at_recall_0.80  	14	0.2500
# iprec_at_recall_0.90  	14	0.2500
# iprec_at_recall_1.00  	14	0.2500
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	7
# num_rel               	16	7
# num_rel_ret           	16	0
# map                   	16	0.0000
# Rprec                 	16	0.0000
# bpref                 	16	0.0000
# recip_rank            	16	0.0000
# iprec_at_recall_0.00  	16	0.0000
# iprec_at_recall_0.10  	16	0.0000
# iprec_at_recall_0.20  	16	0.0000
# iprec_at_recall_0.30  	16	0.0000
# iprec_at_recall_0.40  	16	0.0000
# iprec_at_recall_0.50  	16	0.0000
# iprec_at_recall_0.60  	16	0.0000
# iprec_at_recall_0.70  	16	0.0000
# iprec_at_recall_0.80  	16	0.0000
# iprec_at_recall_0.90  	16	0.0000
# iprec_at_recall_1.00  	16	0.0000
# P_5                   	16	0.0000
# P_10                  	16	0.0000
# P_15                  	16	0.0000
# P_20                  	16	0.0000
# P_30                  	16	0.0000
# P_100                 	16	0.0000
# P_200                 	16	0.0000
# P_500                 	16	0.0000
# P_1000                	16	0.0000
# num_ret               	18	17
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	2	6
# num_rel               	2	2
# num_rel_ret           	2	0
# map                   	2	0.0000
# Rprec                 	2	0.0000
# bpref                 	2	0.0000
# recip_rank            	2	0.0000
# iprec_at_recall_0.00  	2	0.0000
# iprec_at_recall_0.10  	2	0.0000
# iprec_at_recall_0.20  	2	0.0000
# iprec_at_recall_0.30  	2	0.0000
# iprec_at_recall_0.40  	2	0.0000
# iprec_at_recall_0.50  	2	0.0000
# iprec_at_recall_0.60  	2	0.0000
# iprec_at_recall_0.70  	2	0.0000
# iprec_at_recall_0.80  	2	0.0000
# iprec_at_recall_0.90  	2	0.0000
# iprec_at_recall_1.00  	2	0.0000
# P_5                   	2	0.0000
# P_10                  	2	0.0000
# P_15                  	2	0.0000
# P_20                  	2	0.0000
# P_30                  	2	0.0000
# P_100                 	2	0.0000
# P_200                 	2	0.0000
# P_500                 	2	0.0000
# P_1000                	2	0.0000
# num_ret               	22	17
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.2000
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.2000
# iprec_at_recall_0.00  	22	0.2000
# iprec_at_recall_0.10  	22	0.2000
# iprec_at_recall_0.20  	22	0.2000
# iprec_at_recall_0.30  	22	0.2000
# iprec_at_recall_0.40  	22	0.2000
# iprec_at_recall_0.50  	22	0.2000
# iprec_at_recall_0.60  	22	0.2000
# iprec_at_recall_0.70  	22	0.2000
# iprec_at_recall_0.80  	22	0.2000
# iprec_at_recall_0.90  	22	0.2000
# iprec_at_recall_1.00  	22	0.2000
# P_5                   	22	0.2000
# P_10                  	22	0.1000
# P_15                  	22	0.0667
# P_20                  	22	0.0500
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	7
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	25
# num_rel               	26	3
# num_rel_ret           	26	1
# map                   	26	0.1111
# Rprec                 	26	0.3333
# bpref                 	26	0.1111
# recip_rank            	26	0.3333
# iprec_at_recall_0.00  	26	0.3333
# iprec_at_recall_0.10  	26	0.3333
# iprec_at_recall_0.20  	26	0.3333
# iprec_at_recall_0.30  	26	0.3333
# iprec_at_recall_0.40  	26	0.0000
# iprec_at_recall_0.50  	26	0.0000
# iprec_at_recall_0.60  	26	0.0000
# iprec_at_recall_0.70  	26	0.0000
# iprec_at_recall_0.80  	26	0.0000
# iprec_at_recall_0.90  	26	0.0000
# iprec_at_recall_1.00  	26	0.0000
# P_5                   	26	0.2000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0333
# P_100                 	26	0.0100
# P_200                 	26	0.0050
# P_500                 	26	0.0020
# P_1000                	26	0.0010
# num_ret               	28	22
# num_rel               	28	2
# num_rel_ret           	28	0
# map                   	28	0.0000
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.0000
# iprec_at_recall_0.00  	28	0.0000
# iprec_at_recall_0.10  	28	0.0000
# iprec_at_recall_0.20  	28	0.0000
# iprec_at_recall_0.30  	28	0.0000
# iprec_at_recall_0.40  	28	0.0000
# iprec_at_recall_0.50  	28	0.0000
# iprec_at_recall_0.60  	28	0.0000
# iprec_at_recall_0.70  	28	0.0000
# iprec_at_recall_0.80  	28	0.0000
# iprec_at_recall_0.90  	28	0.0000
# iprec_at_recall_1.00  	28	0.0000
# P_5                   	28	0.0000
# P_10                  	28	0.0000
# P_15                  	28	0.0000
# P_20                  	28	0.0000
# P_30                  	28	0.0000
# P_100                 	28	0.0000
# P_200                 	28	0.0000
# P_500                 	28	0.0000
# P_1000                	28	0.0000
# num_ret               	4	12
# num_rel               	4	4
# num_rel_ret           	4	1
# map                   	4	0.0312
# Rprec                 	4	0.0000
# bpref                 	4	0.0000
# recip_rank            	4	0.1250
# iprec_at_recall_0.00  	4	0.1250
# iprec_at_recall_0.10  	4	0.1250
# iprec_at_recall_0.20  	4	0.1250
# iprec_at_recall_0.30  	4	0.0000
# iprec_at_recall_0.40  	4	0.0000
# iprec_at_recall_0.50  	4	0.0000
# iprec_at_recall_0.60  	4	0.0000
# iprec_at_recall_0.70  	4	0.0000
# iprec_at_recall_0.80  	4	0.0000
# iprec_at_recall_0.90  	4	0.0000
# iprec_at_recall_1.00  	4	0.0000
# P_5                   	4	0.0000
# P_10                  	4	0.1000
# P_15                  	4	0.0667
# P_20                  	4	0.0500
# P_30                  	4	0.0333
# P_100                 	4	0.0100
# P_200                 	4	0.0050
# P_500                 	4	0.0020
# P_1000                	4	0.0010
# num_ret               	6	5
# num_rel               	6	1
# num_rel_ret           	6	0
# map                   	6	0.0000
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.0000
# iprec_at_recall_0.00  	6	0.0000
# iprec_at_recall_0.10  	6	0.0000
# iprec_at_recall_0.20  	6	0.0000
# iprec_at_recall_0.30  	6	0.0000
# iprec_at_recall_0.40  	6	0.0000
# iprec_at_recall_0.50  	6	0.0000
# iprec_at_recall_0.60  	6	0.0000
# iprec_at_recall_0.70  	6	0.0000
# iprec_at_recall_0.80  	6	0.0000
# iprec_at_recall_0.90  	6	0.0000
# iprec_at_recall_1.00  	6	0.0000
# P_5                   	6	0.0000
# P_10                  	6	0.0000
# P_15                  	6	0.0000
# P_20                  	6	0.0000
# P_30                  	6	0.0000
# P_100                 	6	0.0000
# P_200                 	6	0.0000
# P_500                 	6	0.0000
# P_1000                	6	0.0000
# num_ret               	7	7
# num_rel               	7	3
# num_rel_ret           	7	0
# map                   	7	0.0000
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.0000
# iprec_at_recall_0.00  	7	0.0000
# iprec_at_recall_0.10  	7	0.0000
# iprec_at_recall_0.20  	7	0.0000
# iprec_at_recall_0.30  	7	0.0000
# iprec_at_recall_0.40  	7	0.0000
# iprec_at_recall_0.50  	7	0.0000
# iprec_at_recall_0.60  	7	0.0000
# iprec_at_recall_0.70  	7	0.0000
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.0000
# P_10                  	7	0.0000
# P_15                  	7	0.0000
# P_20                  	7	0.0000
# P_30                  	7	0.0000
# P_100                 	7	0.0000
# P_200                 	7	0.0000
# P_500                 	7	0.0000
# P_1000                	7	0.0000
# num_ret               	9	2
# num_rel               	9	1
# num_rel_ret           	9	0
# map                   	9	0.0000
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.0000
# iprec_at_recall_0.00  	9	0.0000
# iprec_at_recall_0.10  	9	0.0000
# iprec_at_recall_0.20  	9	0.0000
# iprec_at_recall_0.30  	9	0.0000
# iprec_at_recall_0.40  	9	0.0000
# iprec_at_recall_0.50  	9	0.0000
# iprec_at_recall_0.60  	9	0.0000
# iprec_at_recall_0.70  	9	0.0000
# iprec_at_recall_0.80  	9	0.0000
# iprec_at_recall_0.90  	9	0.0000
# iprec_at_recall_1.00  	9	0.0000
# P_5                   	9	0.0000
# P_10                  	9	0.0000
# P_15                  	9	0.0000
# P_20                  	9	0.0000
# P_30                  	9	0.0000
# P_100                 	9	0.0000
# P_200                 	9	0.0000
# P_500                 	9	0.0000
# P_1000                	9	0.0000
# runid                 	all	test
# num_q                 	all	14
# num_ret               	all	151
# num_rel               	all	33
# num_rel_ret           	all	7
# map                   	all	0.1971
# gm_map                	all	0.0015
# Rprec                 	all	0.1667
# bpref                 	all	0.1508
# recip_rank            	all	0.2196
# iprec_at_recall_0.00  	all	0.2196
# iprec_at_recall_0.10  	all	0.2196
# iprec_at_recall_0.20  	all	0.2196
# iprec_at_recall_0.30  	all	0.2107
# iprec_at_recall_0.40  	all	0.1869
# iprec_at_recall_0.50  	all	0.1869
# iprec_at_recall_0.60  	all	0.1869
# iprec_at_recall_0.70  	all	0.1869
# iprec_at_recall_0.80  	all	0.1869
# iprec_at_recall_0.90  	all	0.1869
# iprec_at_recall_1.00  	all	0.1869
# P_5                   	all	0.0714
# P_10                  	all	0.0500
# P_15                  	all	0.0333
# P_20                  	all	0.0250
# P_30                  	all	0.0167
# P_100                 	all	0.0050
# P_200                 	all	0.0025
# P_500                 	all	0.0010
# P_1000                	all	0.0005

# %%
# Is it empty?
print("Index is empty?", myIndex.is_empty())

# How many files indexed?
print("Number of indexed files:", myIndex.doc_count())
# Out:
# Index is empty? False
# Number of indexed files: 4078

# %%
# define a reader object on the index
myReader = myIndex.reader()

# %%
# run a sample query for the phrase "cotton"
sampleQuery = myQueryParser.parse("juvenile delinquency")
sampleQueryResults = mySearcher.search(sampleQuery, limit=None)

# inspect the result:
# for each document print the rank and the score
for (docnum, result) in enumerate(sampleQueryResults):
    score = sampleQueryResults.score(docnum)
    fileName = os.path.basename(result["file_path"])
    print(fileName, docnum, score)
# Out:
# G00-22-3396139 0 17.26213868755707
# G00-76-0415824 1 10.597054574626043
# G00-78-1531079 2 8.77864826829756
# G00-15-1718631 3 8.076859679154353
# G00-70-2787853 4 6.788751086401821
# G00-74-1394517 5 3.368379609499579

# %%
# how many documents have the phares "bit", blob"
#   in the field "file_content"?
print("# docs with 'juvenile'", myReader.doc_frequency("file_content", "juvenile"))
print("# docs with 'delinquency'", myReader.doc_frequency("file_content", "delinquency"))
print("# docs with 'juvenile delinquency'", myReader.doc_frequency("file_content", "juvenile delinquency"))
# Out:
# # docs with 'juvenile' 19
# # docs with 'delinquency' 6
# # docs with 'juvenile delinquency' 0

# %%
INDEX_Q2 = myIndex # Replace None with your index for Q2
QP_Q2 = myQueryParser # Replace None with your query parser for Q2
SEARCHER_Q2 = mySearcher # Replace None with your searcher for Q2

# %% [markdown]
# ### Q2 (b): Provide answer to Q2 (b) here [markdown cell]

# %% [markdown]
# It didn't do so well, by considering MAP scored 0.1971/1, there is still a lot can be improved.

# %% [markdown]
# ### Q2 (c): Provide answer to Q2(c) here [markdown cell]

# %% [markdown]
# Topic 1 2 6 7 9 16 28 are bad because they scored zero, which mean all retrived documents are irrelevent.
# Topic 18 and 24 did very well because the most relevant documents ranked on the top.

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Q3 (a): Provide answer to Q3 (a) here [markdown cell]

# %% [markdown]
# For example, in topic 2-juvenile delinquency, No 1 ranked doc G00-22-3396139 scored 17.2 in the baseline Whoosh system, but this document is actually irrelevant. This is a case of false positive (FP). Although words “juvenile” and “delinquency” appeared in the documents, the document just listed some government agencies which includes “the Office of Juvenile Justice and Delinquency Prevention” twice. In addition, this document is very short which means high term frequency for “juvenile delinquency”.  However, this article in general is just talking about OFFICE OF JUSTICE PROGRAMS. Similarly, there are lots of documents that include topics’ key words but they are irrelevant.
#
# Other the other hand, doc G00-37-1427392 is relevant but not been queried. This is a case of false negative (FN). The reason why this document ranked low is that no key words are been matched. With the base line RegexTokenizer, searcher was not able to detect Capitalized “juvenile” and “delinquency”. By implementing more advanced tokenizer, false negative should be reduced, and overall result should be improved.

# %% [markdown]
# ### Q3 (b): Write your code below

# %%
# Put your code for creating the index here (you can add more cells).
# Make sure you save the final index in the variable INDEX_Q3, your query parser in QP_Q3, and your searcher in SEARCHER_Q3
mynewSchema = Schema(file_path = ID(stored=True),
                  file_content = TEXT(analyzer = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | StemFilter()))

# now, create the index at the path INDEX_DIR based on the new schema
mynewIndex = createIndex(mynewSchema)

# %%
addFilesToIndex(mynewIndex, filesToIndex)
mynewQueryParser = QueryParser("file_content", schema=mynewIndex.schema)
mynewSearcher = mynewIndex.searcher()
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
trecEval(TOPIC_FILE, QRELS_FILE, mynewQueryParser, mynewSearcher)
# Out:
# num_ret               	1	3
# num_rel               	1	5
# num_rel_ret           	1	0
# map                   	1	0.0000
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0000
# iprec_at_recall_0.00  	1	0.0000
# iprec_at_recall_0.10  	1	0.0000
# iprec_at_recall_0.20  	1	0.0000
# iprec_at_recall_0.30  	1	0.0000
# iprec_at_recall_0.40  	1	0.0000
# iprec_at_recall_0.50  	1	0.0000
# iprec_at_recall_0.60  	1	0.0000
# iprec_at_recall_0.70  	1	0.0000
# iprec_at_recall_0.80  	1	0.0000
# iprec_at_recall_0.90  	1	0.0000
# iprec_at_recall_1.00  	1	0.0000
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0000
# P_30                  	1	0.0000
# P_100                 	1	0.0000
# P_200                 	1	0.0000
# P_500                 	1	0.0000
# P_1000                	1	0.0000
# num_ret               	10	42
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.2500
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.2500
# iprec_at_recall_0.00  	10	0.2500
# iprec_at_recall_0.10  	10	0.2500
# iprec_at_recall_0.20  	10	0.2500
# iprec_at_recall_0.30  	10	0.2500
# iprec_at_recall_0.40  	10	0.2500
# iprec_at_recall_0.50  	10	0.2500
# iprec_at_recall_0.60  	10	0.2500
# iprec_at_recall_0.70  	10	0.2500
# iprec_at_recall_0.80  	10	0.2500
# iprec_at_recall_0.90  	10	0.2500
# iprec_at_recall_1.00  	10	0.2500
# P_5                   	10	0.2000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	26
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	1.0000
# Rprec                 	14	1.0000
# bpref                 	14	1.0000
# recip_rank            	14	1.0000
# iprec_at_recall_0.00  	14	1.0000
# iprec_at_recall_0.10  	14	1.0000
# iprec_at_recall_0.20  	14	1.0000
# iprec_at_recall_0.30  	14	1.0000
# iprec_at_recall_0.40  	14	1.0000
# iprec_at_recall_0.50  	14	1.0000
# iprec_at_recall_0.60  	14	1.0000
# iprec_at_recall_0.70  	14	1.0000
# iprec_at_recall_0.80  	14	1.0000
# iprec_at_recall_0.90  	14	1.0000
# iprec_at_recall_1.00  	14	1.0000
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	24
# num_rel               	16	7
# num_rel_ret           	16	0
# map                   	16	0.0000
# Rprec                 	16	0.0000
# bpref                 	16	0.0000
# recip_rank            	16	0.0000
# iprec_at_recall_0.00  	16	0.0000
# iprec_at_recall_0.10  	16	0.0000
# iprec_at_recall_0.20  	16	0.0000
# iprec_at_recall_0.30  	16	0.0000
# iprec_at_recall_0.40  	16	0.0000
# iprec_at_recall_0.50  	16	0.0000
# iprec_at_recall_0.60  	16	0.0000
# iprec_at_recall_0.70  	16	0.0000
# iprec_at_recall_0.80  	16	0.0000
# iprec_at_recall_0.90  	16	0.0000
# iprec_at_recall_1.00  	16	0.0000
# P_5                   	16	0.0000
# P_10                  	16	0.0000
# P_15                  	16	0.0000
# P_20                  	16	0.0000
# P_30                  	16	0.0000
# P_100                 	16	0.0000
# P_200                 	16	0.0000
# P_500                 	16	0.0000
# P_1000                	16	0.0000
# num_ret               	18	32
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	19	5
# num_rel               	19	2
# num_rel_ret           	19	1
# map                   	19	0.5000
# Rprec                 	19	0.5000
# bpref                 	19	0.5000
# recip_rank            	19	1.0000
# iprec_at_recall_0.00  	19	1.0000
# iprec_at_recall_0.10  	19	1.0000
# iprec_at_recall_0.20  	19	1.0000
# iprec_at_recall_0.30  	19	1.0000
# iprec_at_recall_0.40  	19	1.0000
# iprec_at_recall_0.50  	19	1.0000
# iprec_at_recall_0.60  	19	0.0000
# iprec_at_recall_0.70  	19	0.0000
# iprec_at_recall_0.80  	19	0.0000
# iprec_at_recall_0.90  	19	0.0000
# iprec_at_recall_1.00  	19	0.0000
# P_5                   	19	0.2000
# P_10                  	19	0.1000
# P_15                  	19	0.0667
# P_20                  	19	0.0500
# P_30                  	19	0.0333
# P_100                 	19	0.0100
# P_200                 	19	0.0050
# P_500                 	19	0.0020
# P_1000                	19	0.0010
# num_ret               	2	13
# num_rel               	2	2
# num_rel_ret           	2	1
# map                   	2	0.5000
# Rprec                 	2	0.5000
# bpref                 	2	0.5000
# recip_rank            	2	1.0000
# iprec_at_recall_0.00  	2	1.0000
# iprec_at_recall_0.10  	2	1.0000
# iprec_at_recall_0.20  	2	1.0000
# iprec_at_recall_0.30  	2	1.0000
# iprec_at_recall_0.40  	2	1.0000
# iprec_at_recall_0.50  	2	1.0000
# iprec_at_recall_0.60  	2	0.0000
# iprec_at_recall_0.70  	2	0.0000
# iprec_at_recall_0.80  	2	0.0000
# iprec_at_recall_0.90  	2	0.0000
# iprec_at_recall_1.00  	2	0.0000
# P_5                   	2	0.2000
# P_10                  	2	0.1000
# P_15                  	2	0.0667
# P_20                  	2	0.0500
# P_30                  	2	0.0333
# P_100                 	2	0.0100
# P_200                 	2	0.0050
# P_500                 	2	0.0020
# P_1000                	2	0.0010
# num_ret               	22	107
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.0385
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.0385
# iprec_at_recall_0.00  	22	0.0385
# iprec_at_recall_0.10  	22	0.0385
# iprec_at_recall_0.20  	22	0.0385
# iprec_at_recall_0.30  	22	0.0385
# iprec_at_recall_0.40  	22	0.0385
# iprec_at_recall_0.50  	22	0.0385
# iprec_at_recall_0.60  	22	0.0385
# iprec_at_recall_0.70  	22	0.0385
# iprec_at_recall_0.80  	22	0.0385
# iprec_at_recall_0.90  	22	0.0385
# iprec_at_recall_1.00  	22	0.0385
# P_5                   	22	0.0000
# P_10                  	22	0.0000
# P_15                  	22	0.0000
# P_20                  	22	0.0000
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	20
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	51
# num_rel               	26	3
# num_rel_ret           	26	2
# map                   	26	0.0771
# Rprec                 	26	0.0000
# bpref                 	26	0.0000
# recip_rank            	26	0.1667
# iprec_at_recall_0.00  	26	0.1667
# iprec_at_recall_0.10  	26	0.1667
# iprec_at_recall_0.20  	26	0.1667
# iprec_at_recall_0.30  	26	0.1667
# iprec_at_recall_0.40  	26	0.0645
# iprec_at_recall_0.50  	26	0.0645
# iprec_at_recall_0.60  	26	0.0645
# iprec_at_recall_0.70  	26	0.0645
# iprec_at_recall_0.80  	26	0.0000
# iprec_at_recall_0.90  	26	0.0000
# iprec_at_recall_1.00  	26	0.0000
# P_5                   	26	0.0000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0333
# P_100                 	26	0.0200
# P_200                 	26	0.0100
# P_500                 	26	0.0040
# P_1000                	26	0.0020
# num_ret               	28	37
# num_rel               	28	2
# num_rel_ret           	28	2
# map                   	28	0.0711
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.0588
# iprec_at_recall_0.00  	28	0.0833
# iprec_at_recall_0.10  	28	0.0833
# iprec_at_recall_0.20  	28	0.0833
# iprec_at_recall_0.30  	28	0.0833
# iprec_at_recall_0.40  	28	0.0833
# iprec_at_recall_0.50  	28	0.0833
# iprec_at_recall_0.60  	28	0.0833
# iprec_at_recall_0.70  	28	0.0833
# iprec_at_recall_0.80  	28	0.0833
# iprec_at_recall_0.90  	28	0.0833
# iprec_at_recall_1.00  	28	0.0833
# P_5                   	28	0.0000
# P_10                  	28	0.0000
# P_15                  	28	0.0000
# P_20                  	28	0.0500
# P_30                  	28	0.0667
# P_100                 	28	0.0200
# P_200                 	28	0.0100
# P_500                 	28	0.0040
# P_1000                	28	0.0020
# num_ret               	4	40
# num_rel               	4	4
# num_rel_ret           	4	3
# map                   	4	0.5357
# Rprec                 	4	0.5000
# bpref                 	4	0.5000
# recip_rank            	4	1.0000
# iprec_at_recall_0.00  	4	1.0000
# iprec_at_recall_0.10  	4	1.0000
# iprec_at_recall_0.20  	4	1.0000
# iprec_at_recall_0.30  	4	1.0000
# iprec_at_recall_0.40  	4	1.0000
# iprec_at_recall_0.50  	4	1.0000
# iprec_at_recall_0.60  	4	0.1429
# iprec_at_recall_0.70  	4	0.1429
# iprec_at_recall_0.80  	4	0.0000
# iprec_at_recall_0.90  	4	0.0000
# iprec_at_recall_1.00  	4	0.0000
# P_5                   	4	0.4000
# P_10                  	4	0.2000
# P_15                  	4	0.1333
# P_20                  	4	0.1000
# P_30                  	4	0.1000
# P_100                 	4	0.0300
# P_200                 	4	0.0150
# P_500                 	4	0.0060
# P_1000                	4	0.0030
# num_ret               	6	13
# num_rel               	6	1
# num_rel_ret           	6	0
# map                   	6	0.0000
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.0000
# iprec_at_recall_0.00  	6	0.0000
# iprec_at_recall_0.10  	6	0.0000
# iprec_at_recall_0.20  	6	0.0000
# iprec_at_recall_0.30  	6	0.0000
# iprec_at_recall_0.40  	6	0.0000
# iprec_at_recall_0.50  	6	0.0000
# iprec_at_recall_0.60  	6	0.0000
# iprec_at_recall_0.70  	6	0.0000
# iprec_at_recall_0.80  	6	0.0000
# iprec_at_recall_0.90  	6	0.0000
# iprec_at_recall_1.00  	6	0.0000
# P_5                   	6	0.0000
# P_10                  	6	0.0000
# P_15                  	6	0.0000
# P_20                  	6	0.0000
# P_30                  	6	0.0000
# P_100                 	6	0.0000
# P_200                 	6	0.0000
# P_500                 	6	0.0000
# P_1000                	6	0.0000
# num_ret               	7	14
# num_rel               	7	3
# num_rel_ret           	7	0
# map                   	7	0.0000
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.0000
# iprec_at_recall_0.00  	7	0.0000
# iprec_at_recall_0.10  	7	0.0000
# iprec_at_recall_0.20  	7	0.0000
# iprec_at_recall_0.30  	7	0.0000
# iprec_at_recall_0.40  	7	0.0000
# iprec_at_recall_0.50  	7	0.0000
# iprec_at_recall_0.60  	7	0.0000
# iprec_at_recall_0.70  	7	0.0000
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.0000
# P_10                  	7	0.0000
# P_15                  	7	0.0000
# P_20                  	7	0.0000
# P_30                  	7	0.0000
# P_100                 	7	0.0000
# P_200                 	7	0.0000
# P_500                 	7	0.0000
# P_1000                	7	0.0000
# num_ret               	9	27
# num_rel               	9	1
# num_rel_ret           	9	1
# map                   	9	0.0769
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.0769
# iprec_at_recall_0.00  	9	0.0769
# iprec_at_recall_0.10  	9	0.0769
# iprec_at_recall_0.20  	9	0.0769
# iprec_at_recall_0.30  	9	0.0769
# iprec_at_recall_0.40  	9	0.0769
# iprec_at_recall_0.50  	9	0.0769
# iprec_at_recall_0.60  	9	0.0769
# iprec_at_recall_0.70  	9	0.0769
# iprec_at_recall_0.80  	9	0.0769
# iprec_at_recall_0.90  	9	0.0769
# iprec_at_recall_1.00  	9	0.0769
# P_5                   	9	0.0000
# P_10                  	9	0.0000
# P_15                  	9	0.0667
# P_20                  	9	0.0500
# P_30                  	9	0.0333
# P_100                 	9	0.0100
# P_200                 	9	0.0050
# P_500                 	9	0.0020
# P_1000                	9	0.0010
# runid                 	all	test
# num_q                 	all	15
# num_ret               	all	454
# num_rel               	all	35
# num_rel_ret           	all	15
# map                   	all	0.3366
# gm_map                	all	0.0177
# Rprec                 	all	0.3000
# bpref                 	all	0.3000
# recip_rank            	all	0.4394
# iprec_at_recall_0.00  	all	0.4410
# iprec_at_recall_0.10  	all	0.4410
# iprec_at_recall_0.20  	all	0.4410
# iprec_at_recall_0.30  	all	0.4410
# iprec_at_recall_0.40  	all	0.4342
# iprec_at_recall_0.50  	all	0.4342
# iprec_at_recall_0.60  	all	0.2437
# iprec_at_recall_0.70  	all	0.2437
# iprec_at_recall_0.80  	all	0.2299
# iprec_at_recall_0.90  	all	0.2299
# iprec_at_recall_1.00  	all	0.2299
# P_5                   	all	0.1067
# P_10                  	all	0.0600
# P_15                  	all	0.0444
# P_20                  	all	0.0367
# P_30                  	all	0.0311
# P_100                 	all	0.0100
# P_200                 	all	0.0050
# P_500                 	all	0.0020
# P_1000                	all	0.0010

# %%
# run a sample query for the phrase "cotton"
samplenewQuery = mynewQueryParser.parse("juvenile delinquency")
samplenewQueryResults = mynewSearcher.search(samplenewQuery, limit=None)

# inspect the result:
# for each document print the rank and the score
for (docnum, result) in enumerate(samplenewQueryResults):
    score = samplenewQueryResults.score(docnum)
    fileName = os.path.basename(result["file_path"])
    print(fileName, docnum, score)
# Out:
# G00-37-1427392 0 19.449213860332442
# G00-22-3396139 1 18.434193291655042
# G00-78-1531079 2 16.335289209741667
# G00-92-0578141 3 15.493780459238984
# G00-67-0637954 4 14.85795689433918
# G00-91-1567424 5 14.721796656533094
# G00-94-1117794 6 13.437583261488802
# G00-76-0415824 7 12.54308590417346
# G00-15-1718631 8 11.522913461281409
# G00-90-3871013 9 11.372035203185476
# G00-70-2787853 10 10.268645726545305
# G00-27-2159399 11 8.788646752754644
# G00-74-1394517 12 4.022868439339689

# %%
INDEX_Q3 = mynewIndex # Replace None with your index for Q3
QP_Q3 = mynewQueryParser # Replace None with your query parser for Q3
SEARCHER_Q3 = mynewSearcher # Replace None with your searcher for Q3

# %% [markdown]
# ### Q3 (c): Provide answer to Q3 (c) here [markdown cell]

# %% [markdown]
# As I mentioned I included a more complexed Tokenizer that lowercases everything, strips stop words, break phrases and stems words. By doing so, false negative reduced and both true positive and false positive increased.however, qrery is able to retrive Topic 2 9 28 with relevant result now.

# %% [markdown]
# ### Q3 (d): Provide answer to Q3 (d) here [markdown cell]

# %% [markdown]
# Yes

# %% [markdown]
# ### Q3 (e): Provide answer to Q3 (e) here [markdown cell]

# %% [markdown]
# Yes

# %% [markdown]
# ### Q3 (f): Provide answer to Q3 (f) here [markdown cell]

# %% [markdown]
# It still means good, since the improved quries are improved signifcantlly. Map improved from 0.19 to 0.33. Those quries that got worse only got worse a little bit, and their relevant result still retrived. They only ranked down by one place or two.

# %% [markdown]
# ## Question 4 (Graduate Students)

# %%
GRAD_STUDENT = True # change to True if you are a grad student

# %% [markdown]
# ### Q4 (a): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# Since this alternative method is just a small varition of the Q3's query, result should be pretty similar. With the fine tune of the free peremeter, I am aimming to improve the rank of some of the relevant documents. By tuning B and K1, I can vary the weight of overall document length and term frequency.

# %% [markdown]
# ### Q4 (b): Write your code below

# %%
# Put your code for creating the index here (you can add more cells).
# Make sure you save the final index in the variable INDEX_Q4, your query parser in QP_Q4, and your searcher in SEARCHER_Q4
# first, define a Schema for the index
from whoosh import scoring
mynextSchema = Schema(file_path = ID(stored=True),
                  file_content = TEXT(analyzer =  RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | StemFilter()))

# now, create the index at the path INDEX_DIR based on the new schema
mynextIndex = createIndex(mynextSchema)

# %%
addFilesToIndex(mynextIndex, filesToIndex)
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
mynextQueryParser = QueryParser("file_content", schema=mynextIndex.schema)
#mynextSearcher = mynextIndex.searcher(weighting=scoring.TF_IDF())
mynextSearcher = mynextIndex.searcher(weighting=scoring.BM25F(B=0.3, K1=0.01))

# %%
trecEval(TOPIC_FILE, QRELS_FILE, mynextQueryParser, mynextSearcher)
# Out:
# num_ret               	1	3
# num_rel               	1	5
# num_rel_ret           	1	0
# map                   	1	0.0000
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0000
# iprec_at_recall_0.00  	1	0.0000
# iprec_at_recall_0.10  	1	0.0000
# iprec_at_recall_0.20  	1	0.0000
# iprec_at_recall_0.30  	1	0.0000
# iprec_at_recall_0.40  	1	0.0000
# iprec_at_recall_0.50  	1	0.0000
# iprec_at_recall_0.60  	1	0.0000
# iprec_at_recall_0.70  	1	0.0000
# iprec_at_recall_0.80  	1	0.0000
# iprec_at_recall_0.90  	1	0.0000
# iprec_at_recall_1.00  	1	0.0000
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0000
# P_30                  	1	0.0000
# P_100                 	1	0.0000
# P_200                 	1	0.0000
# P_500                 	1	0.0000
# P_1000                	1	0.0000
# num_ret               	10	42
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.3333
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.3333
# iprec_at_recall_0.00  	10	0.3333
# iprec_at_recall_0.10  	10	0.3333
# iprec_at_recall_0.20  	10	0.3333
# iprec_at_recall_0.30  	10	0.3333
# iprec_at_recall_0.40  	10	0.3333
# iprec_at_recall_0.50  	10	0.3333
# iprec_at_recall_0.60  	10	0.3333
# iprec_at_recall_0.70  	10	0.3333
# iprec_at_recall_0.80  	10	0.3333
# iprec_at_recall_0.90  	10	0.3333
# iprec_at_recall_1.00  	10	0.3333
# P_5                   	10	0.2000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	26
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	1.0000
# Rprec                 	14	1.0000
# bpref                 	14	1.0000
# recip_rank            	14	1.0000
# iprec_at_recall_0.00  	14	1.0000
# iprec_at_recall_0.10  	14	1.0000
# iprec_at_recall_0.20  	14	1.0000
# iprec_at_recall_0.30  	14	1.0000
# iprec_at_recall_0.40  	14	1.0000
# iprec_at_recall_0.50  	14	1.0000
# iprec_at_recall_0.60  	14	1.0000
# iprec_at_recall_0.70  	14	1.0000
# iprec_at_recall_0.80  	14	1.0000
# iprec_at_recall_0.90  	14	1.0000
# iprec_at_recall_1.00  	14	1.0000
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	24
# num_rel               	16	7
# num_rel_ret           	16	0
# map                   	16	0.0000
# Rprec                 	16	0.0000
# bpref                 	16	0.0000
# recip_rank            	16	0.0000
# iprec_at_recall_0.00  	16	0.0000
# iprec_at_recall_0.10  	16	0.0000
# iprec_at_recall_0.20  	16	0.0000
# iprec_at_recall_0.30  	16	0.0000
# iprec_at_recall_0.40  	16	0.0000
# iprec_at_recall_0.50  	16	0.0000
# iprec_at_recall_0.60  	16	0.0000
# iprec_at_recall_0.70  	16	0.0000
# iprec_at_recall_0.80  	16	0.0000
# iprec_at_recall_0.90  	16	0.0000
# iprec_at_recall_1.00  	16	0.0000
# P_5                   	16	0.0000
# P_10                  	16	0.0000
# P_15                  	16	0.0000
# P_20                  	16	0.0000
# P_30                  	16	0.0000
# P_100                 	16	0.0000
# P_200                 	16	0.0000
# P_500                 	16	0.0000
# P_1000                	16	0.0000
# num_ret               	18	32
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	19	5
# num_rel               	19	2
# num_rel_ret           	19	1
# map                   	19	0.5000
# Rprec                 	19	0.5000
# bpref                 	19	0.5000
# recip_rank            	19	1.0000
# iprec_at_recall_0.00  	19	1.0000
# iprec_at_recall_0.10  	19	1.0000
# iprec_at_recall_0.20  	19	1.0000
# iprec_at_recall_0.30  	19	1.0000
# iprec_at_recall_0.40  	19	1.0000
# iprec_at_recall_0.50  	19	1.0000
# iprec_at_recall_0.60  	19	0.0000
# iprec_at_recall_0.70  	19	0.0000
# iprec_at_recall_0.80  	19	0.0000
# iprec_at_recall_0.90  	19	0.0000
# iprec_at_recall_1.00  	19	0.0000
# P_5                   	19	0.2000
# P_10                  	19	0.1000
# P_15                  	19	0.0667
# P_20                  	19	0.0500
# P_30                  	19	0.0333
# P_100                 	19	0.0100
# P_200                 	19	0.0050
# P_500                 	19	0.0020
# P_1000                	19	0.0010
# num_ret               	2	13
# num_rel               	2	2
# num_rel_ret           	2	1
# map                   	2	0.5000
# Rprec                 	2	0.5000
# bpref                 	2	0.5000
# recip_rank            	2	1.0000
# iprec_at_recall_0.00  	2	1.0000
# iprec_at_recall_0.10  	2	1.0000
# iprec_at_recall_0.20  	2	1.0000
# iprec_at_recall_0.30  	2	1.0000
# iprec_at_recall_0.40  	2	1.0000
# iprec_at_recall_0.50  	2	1.0000
# iprec_at_recall_0.60  	2	0.0000
# iprec_at_recall_0.70  	2	0.0000
# iprec_at_recall_0.80  	2	0.0000
# iprec_at_recall_0.90  	2	0.0000
# iprec_at_recall_1.00  	2	0.0000
# P_5                   	2	0.2000
# P_10                  	2	0.1000
# P_15                  	2	0.0667
# P_20                  	2	0.0500
# P_30                  	2	0.0333
# P_100                 	2	0.0100
# P_200                 	2	0.0050
# P_500                 	2	0.0020
# P_1000                	2	0.0010
# num_ret               	22	107
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.0556
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.0556
# iprec_at_recall_0.00  	22	0.0556
# iprec_at_recall_0.10  	22	0.0556
# iprec_at_recall_0.20  	22	0.0556
# iprec_at_recall_0.30  	22	0.0556
# iprec_at_recall_0.40  	22	0.0556
# iprec_at_recall_0.50  	22	0.0556
# iprec_at_recall_0.60  	22	0.0556
# iprec_at_recall_0.70  	22	0.0556
# iprec_at_recall_0.80  	22	0.0556
# iprec_at_recall_0.90  	22	0.0556
# iprec_at_recall_1.00  	22	0.0556
# P_5                   	22	0.0000
# P_10                  	22	0.0000
# P_15                  	22	0.0000
# P_20                  	22	0.0500
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	20
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	51
# num_rel               	26	3
# num_rel_ret           	26	2
# map                   	26	0.0600
# Rprec                 	26	0.0000
# bpref                 	26	0.0000
# recip_rank            	26	0.1111
# iprec_at_recall_0.00  	26	0.1111
# iprec_at_recall_0.10  	26	0.1111
# iprec_at_recall_0.20  	26	0.1111
# iprec_at_recall_0.30  	26	0.1111
# iprec_at_recall_0.40  	26	0.0690
# iprec_at_recall_0.50  	26	0.0690
# iprec_at_recall_0.60  	26	0.0690
# iprec_at_recall_0.70  	26	0.0690
# iprec_at_recall_0.80  	26	0.0000
# iprec_at_recall_0.90  	26	0.0000
# iprec_at_recall_1.00  	26	0.0000
# P_5                   	26	0.0000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0667
# P_100                 	26	0.0200
# P_200                 	26	0.0100
# P_500                 	26	0.0040
# P_1000                	26	0.0020
# num_ret               	28	37
# num_rel               	28	2
# num_rel_ret           	28	2
# map                   	28	0.2167
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.3333
# iprec_at_recall_0.00  	28	0.3333
# iprec_at_recall_0.10  	28	0.3333
# iprec_at_recall_0.20  	28	0.3333
# iprec_at_recall_0.30  	28	0.3333
# iprec_at_recall_0.40  	28	0.3333
# iprec_at_recall_0.50  	28	0.3333
# iprec_at_recall_0.60  	28	0.1000
# iprec_at_recall_0.70  	28	0.1000
# iprec_at_recall_0.80  	28	0.1000
# iprec_at_recall_0.90  	28	0.1000
# iprec_at_recall_1.00  	28	0.1000
# P_5                   	28	0.2000
# P_10                  	28	0.1000
# P_15                  	28	0.0667
# P_20                  	28	0.1000
# P_30                  	28	0.0667
# P_100                 	28	0.0200
# P_200                 	28	0.0100
# P_500                 	28	0.0040
# P_1000                	28	0.0020
# num_ret               	4	40
# num_rel               	4	4
# num_rel_ret           	4	3
# map                   	4	0.5417
# Rprec                 	4	0.5000
# bpref                 	4	0.5000
# recip_rank            	4	1.0000
# iprec_at_recall_0.00  	4	1.0000
# iprec_at_recall_0.10  	4	1.0000
# iprec_at_recall_0.20  	4	1.0000
# iprec_at_recall_0.30  	4	1.0000
# iprec_at_recall_0.40  	4	1.0000
# iprec_at_recall_0.50  	4	1.0000
# iprec_at_recall_0.60  	4	0.1667
# iprec_at_recall_0.70  	4	0.1667
# iprec_at_recall_0.80  	4	0.0000
# iprec_at_recall_0.90  	4	0.0000
# iprec_at_recall_1.00  	4	0.0000
# P_5                   	4	0.4000
# P_10                  	4	0.2000
# P_15                  	4	0.1333
# P_20                  	4	0.1500
# P_30                  	4	0.1000
# P_100                 	4	0.0300
# P_200                 	4	0.0150
# P_500                 	4	0.0060
# P_1000                	4	0.0030
# num_ret               	6	13
# num_rel               	6	1
# num_rel_ret           	6	0
# map                   	6	0.0000
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.0000
# iprec_at_recall_0.00  	6	0.0000
# iprec_at_recall_0.10  	6	0.0000
# iprec_at_recall_0.20  	6	0.0000
# iprec_at_recall_0.30  	6	0.0000
# iprec_at_recall_0.40  	6	0.0000
# iprec_at_recall_0.50  	6	0.0000
# iprec_at_recall_0.60  	6	0.0000
# iprec_at_recall_0.70  	6	0.0000
# iprec_at_recall_0.80  	6	0.0000
# iprec_at_recall_0.90  	6	0.0000
# iprec_at_recall_1.00  	6	0.0000
# P_5                   	6	0.0000
# P_10                  	6	0.0000
# P_15                  	6	0.0000
# P_20                  	6	0.0000
# P_30                  	6	0.0000
# P_100                 	6	0.0000
# P_200                 	6	0.0000
# P_500                 	6	0.0000
# P_1000                	6	0.0000
# num_ret               	7	14
# num_rel               	7	3
# num_rel_ret           	7	0
# map                   	7	0.0000
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.0000
# iprec_at_recall_0.00  	7	0.0000
# iprec_at_recall_0.10  	7	0.0000
# iprec_at_recall_0.20  	7	0.0000
# iprec_at_recall_0.30  	7	0.0000
# iprec_at_recall_0.40  	7	0.0000
# iprec_at_recall_0.50  	7	0.0000
# iprec_at_recall_0.60  	7	0.0000
# iprec_at_recall_0.70  	7	0.0000
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.0000
# P_10                  	7	0.0000
# P_15                  	7	0.0000
# P_20                  	7	0.0000
# P_30                  	7	0.0000
# P_100                 	7	0.0000
# P_200                 	7	0.0000
# P_500                 	7	0.0000
# P_1000                	7	0.0000
# num_ret               	9	27
# num_rel               	9	1
# num_rel_ret           	9	1
# map                   	9	0.2500
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.2500
# iprec_at_recall_0.00  	9	0.2500
# iprec_at_recall_0.10  	9	0.2500
# iprec_at_recall_0.20  	9	0.2500
# iprec_at_recall_0.30  	9	0.2500
# iprec_at_recall_0.40  	9	0.2500
# iprec_at_recall_0.50  	9	0.2500
# iprec_at_recall_0.60  	9	0.2500
# iprec_at_recall_0.70  	9	0.2500
# iprec_at_recall_0.80  	9	0.2500
# iprec_at_recall_0.90  	9	0.2500
# iprec_at_recall_1.00  	9	0.2500
# P_5                   	9	0.2000
# P_10                  	9	0.1000
# P_15                  	9	0.0667
# P_20                  	9	0.0500
# P_30                  	9	0.0333
# P_100                 	9	0.0100
# P_200                 	9	0.0050
# P_500                 	9	0.0020
# P_1000                	9	0.0010
# runid                 	all	test
# num_q                 	all	15
# num_ret               	all	454
# num_rel               	all	35
# num_rel_ret           	all	15
# map                   	all	0.3638
# gm_map                	all	0.0213
# Rprec                 	all	0.3000
# bpref                 	all	0.3000
# recip_rank            	all	0.4722
# iprec_at_recall_0.00  	all	0.4722
# iprec_at_recall_0.10  	all	0.4722
# iprec_at_recall_0.20  	all	0.4722
# iprec_at_recall_0.30  	all	0.4722
# iprec_at_recall_0.40  	all	0.4694
# iprec_at_recall_0.50  	all	0.4694
# iprec_at_recall_0.60  	all	0.2650
# iprec_at_recall_0.70  	all	0.2650
# iprec_at_recall_0.80  	all	0.2493
# iprec_at_recall_0.90  	all	0.2493
# iprec_at_recall_1.00  	all	0.2493
# P_5                   	all	0.1333
# P_10                  	all	0.0733
# P_15                  	all	0.0489
# P_20                  	all	0.0467
# P_30                  	all	0.0333
# P_100                 	all	0.0100
# P_200                 	all	0.0050
# P_500                 	all	0.0020
# P_1000                	all	0.0010

# %%
INDEX_Q4 = mynextIndex # Replace None with your index for Q4
QP_Q4 =  mynextQueryParser # Replace None with your query parser for Q4
SEARCHER_Q4 = mynextSearcher # Replace None with your searcher for Q4

# %% [markdown]
# ### Q4 (c): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
#  I modified BM25's free peremeters K1 and B. I changed B from 0.75 to 0.3 and K from 1.2 to 0.01. Topic 4 9 10 22 28's relevant documents now ranked higher. TN and FP remains same by comparing with Q3.

# %% [markdown]
# ### Q4 (d): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# Yes

# %% [markdown]
# ### Q4 (e): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# Yes

# %% [markdown]
# ### Q4 (f): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# For this document set and topics, this new alternative method is better. However, this tuning might be biased, and might not work better for a different document set.

# %% [markdown]
# ## Validation

# %%
# Run the following cells to make sure your code returns the correct value types

# %%
from whoosh.index import FileIndex
from whoosh.qparser import QueryParser
from whoosh.searching import Searcher
import os.path

# %% [markdown]
# ### Q2 Validation

# %%
assert(isinstance(INDEX_Q2, FileIndex)), "Index Type"
assert(isinstance(QP_Q2, QueryParser)), "Query Parser Type"
assert(isinstance(SEARCHER_Q2, Searcher)), "Searcher Type"
print("Q2 Types Validated")
# Out:
# Q2 Types Validated

# %% [markdown]
# ### Q3 Validation

# %%
assert(isinstance(INDEX_Q3, FileIndex)), "Index Type"
assert(isinstance(QP_Q3, QueryParser)), "Query Parser Type"
assert(isinstance(SEARCHER_Q3, Searcher)), "Searcher Type"
print("Q3 Types Validated")
# Out:
# Q3 Types Validated

# %% [markdown]
# ### Q4 Validation (Graduate Students)

# %%
assert((not GRAD_STUDENT) or isinstance(INDEX_Q4, FileIndex)), "Index Type"
assert((not GRAD_STUDENT) or isinstance(QP_Q4, QueryParser)), "Query Parser Type"
assert((not GRAD_STUDENT) or isinstance(SEARCHER_Q4, Searcher)), "Searcher Type"
print("Q4 Types Validated")
# Out:
# Q4 Types Validated
